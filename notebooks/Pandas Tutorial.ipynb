# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# # Intro to Pandas

# %% [markdown]
# There are primarily two data structures
# 1. Series
# 2. DataFrame

# %% [markdown]
# ## 1. Series

# %% [markdown]
# - An array of elements with types similar to Numpy
# - Contains an index for each element

# %% [markdown]
# ### 1.1 Create Series

# %%
series_a =  pd.Series([3, 1, 2.3, 'a', True])

# %%
series_a
# Out:
# 0       3
# 1       1
# 2     2.3
# 3       a
# 4    True
# dtype: object

# %%
series_a.values # list all the values in a series
# Out:
# array([3, 1, 2.3, 'a', True], dtype=object)

# %%
series_a.index # list the index values
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# ### 1.2 Let us create a series with int objects

# %%
series_b = pd.Series([1, 4, 2])

# %%
series_b
# Out:
# 0    1
# 1    4
# 2    2
# dtype: int64

# %% [markdown]
# ### 1.3 Access any element with index

# %%
series_b[1] # access the element at position 2 (default starting index is 0)
# Out:
# 4

# %% [markdown]
# ### 1.4 Access multiple elements

# %%
# x:y:z --> access every zth element starting from index x upto index y 
# if x is missing --> consider 0
# if z is missing --> consider all elements

series_b[:2] # access all elements from 0 upto 2 (2 not included) i.e., 0 and 1
# Out:
# 0    1
# 1    3
# dtype: int64

# %% [markdown]
# ### 1.5 Edit any element using index

# %%
series_b[1] = 3

# %%
series_b
# Out:
# 0    1
# 1    3
# 2    2
# dtype: int64

# %% [markdown]
# ### 1.6 Query And Subset

# %%
series_b > 1
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool

# %%
series_b[series_b > 1]
# Out:
# 1    3
# 2    2
# dtype: int64

# %% [markdown]
# ### 1.7 Edit multiple elements

# %%
series_b.loc[series_b>1] = [2, 3]

# %%
series_b
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# ### 1.8 Perform operations

# %%
series_b + 10
# Out:
# 0    11
# 1    12
# 2    13
# dtype: int64

# %%
series_b ** 2
# Out:
# 0    1
# 1    4
# 2    9
# dtype: int64

# %%
np.log(series_b)
# Out:
# 0    0.000000
# 1    0.693147
# 2    1.098612
# dtype: float64

# %% [markdown]
# ### 1.9 Identify null values

# %%
series_c = pd.Series([np.nan, 2, 23, 4])

# %%
series_c
# Out:
# 0     NaN
# 1     2.0
# 2    23.0
# 3     4.0
# dtype: float64

# %%
pd.isnull(series_c)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
pd.notnull(series_c)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# dtype: bool

# %% [markdown]
# ### 1.10 Operate two series of equal length

# %%
series_1 = pd.Series([1, 2, 3])
series_2 = pd.Series([4, 5, 6])

# %%
series_1 + series_2
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %%
series_1 * series_2
# Out:
# 0     4
# 1    10
# 2    18
# dtype: int64

# %% [markdown]
# ### 1.11 Operate two series of unequal length

# %%
series_1 = pd.Series([1, 2, 3])
series_2 = pd.Series([4, 5, 6, 7])

# %%
series_1 + series_2
# Out:
# 0    5.0
# 1    7.0
# 2    9.0
# 3    NaN
# dtype: float64

# %% [markdown]
# ## 2. DataFrame

# %% [markdown]
# - A collection of Series where each Series represents one Column
# - Similar to data represented in Excel/Database tables

# %% [markdown]
# ### 2.1 Create DataFrame

# %%
df_dict = {"a": [1, 2, 3], "b": ['a', 'b', 'c'], "c": [True, False, True]}

# %%
df = pd.DataFrame(df_dict)

# %%
df
# Out:
#    a  b      c
# 0  1  a   True
# 1  2  b  False
# 2  3  c   True

# %%
df_dict = [[1, 2, 3], ['a', 'b', 'c'], [True, False, True]]
df = pd.DataFrame(df_dict, columns = ['a', 'b', 'c'], index=[1, 2, 3])

# %%
df
# Out:
#       a      b     c
# 1     1      2     3
# 2     a      b     c
# 3  True  False  True

# %% [markdown]
# ### 2.2 Reading and Writing

# %%
df = pd.read_csv("../datasets/Oscars-demographics-DFE.csv", encoding='latin1')

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...          award  \
# 0                       1.0          White  ...  Best Director
# ...

# %% [markdown]
# ### 2.3 Subset rows

# %%
len(df)
# Out:
# 441

# %%
df.index = range(100, 541)

# %%
df.loc[100:105] # based on index names
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 100  670454353    False   finalized                   3      2/10/15 3:45
# 101  670454354    False   finalized                   3      2/10/15 2:03
# 102  670454355    False   finalized                   3      2/10/15 2:05
# 103  670454356    False   finalized                   3      2/10/15 2:04
# 104  670454357    False   finalized                   3      2/10/15 1:48
# 105  670454358    False   finalized                   3      2/10/15 3:50
#
#              birthplace  birthplace:confidence date_of_birth  \
# 100   Chisinau, Moldova                    1.0   30-Sep-1895
# 101   Glasgow, Scotland                    1.0    2-Feb-1886
# 102   Chisinau, Moldova                    1.0   30-Sep-1895
# 103         Chicago, Il                    1.0   23-Feb-1899
# 104  Salt Lake City, Ut                    1.0   23-Apr-1894
# 105   Glasgow, Scotland                    1.0    2-Feb-1886
#
# ...

# %%
df.iloc[0:5] # based on actual position of rows
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 100  670454353    False   finalized                   3      2/10/15 3:45
# 101  670454354    False   finalized                   3      2/10/15 2:03
# 102  670454355    False   finalized                   3      2/10/15 2:05
# 103  670454356    False   finalized                   3      2/10/15 2:04
# 104  670454357    False   finalized                   3      2/10/15 1:48
#
#              birthplace  birthplace:confidence date_of_birth  \
# 100   Chisinau, Moldova                    1.0   30-Sep-1895
# 101   Glasgow, Scotland                    1.0    2-Feb-1886
# 102   Chisinau, Moldova                    1.0   30-Sep-1895
# 103         Chicago, Il                    1.0   23-Feb-1899
# 104  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#      date_of_birth:confidence race_ethnicity  ...          award  \
# 100                       1.0          White  ...  Best Director
# ...

# %%
df.head(10)
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 100  670454353    False   finalized                   3      2/10/15 3:45
# 101  670454354    False   finalized                   3      2/10/15 2:03
# 102  670454355    False   finalized                   3      2/10/15 2:05
# 103  670454356    False   finalized                   3      2/10/15 2:04
# 104  670454357    False   finalized                   3      2/10/15 1:48
# 105  670454358    False   finalized                   3      2/10/15 3:50
# 106  670454359    False   finalized                   3      2/10/15 2:07
# 107  670454360    False   finalized                   3      2/10/15 1:46
# 108  670454361    False   finalized                   3      2/10/15 1:47
# 109  670454362    False   finalized                   3      2/10/15 2:05
#
#                     birthplace  birthplace:confidence date_of_birth  \
# 100          Chisinau, Moldova                    1.0   30-Sep-1895
# ...

# %%
df.tail(3)
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 538  670964912    False   finalized                   3      2/10/15 2:03
# 539  670964956    False   finalized                   3      2/10/15 2:01
# 540  670972898    False   finalized                   3      2/10/15 2:01
#
#       birthplace  birthplace:confidence date_of_birth  \
# 538  Chicago, Il                    1.0     26-Jul-22
# 539   Laurel, Ne                    1.0     31-Aug-28
# 540   Nevada, Mo                    1.0      5-Aug-06
#
#      date_of_birth:confidence race_ethnicity  ...                  award  \
# 538                       1.0          White  ...  Best Supporting Actor
# 539                       1.0          White  ...  Best Supporting Actor
# 540                       1.0          White  ...          Best Director
#
#                                         biourl  birthplace_gold  \
# 538  http://www.nndb.com/people/224/000032128/              NaN
# ...

# %%
df.sample(n=10)
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 184  670454437    False   finalized                   3      2/10/15 1:56
# 403  670454656    False   finalized                   3      2/10/15 1:55
# 178  670454431    False   finalized                   3      2/10/15 2:00
# 539  670964956    False   finalized                   3      2/10/15 2:01
# 386  670454639    False   finalized                   3      2/10/15 2:04
# 216  670454469    False   finalized                   3      2/10/15 2:03
# 179  670454432    False   finalized                   3      2/10/15 2:09
# 341  670454594    False   finalized                   3      2/10/15 3:55
# 379  670454632    False   finalized                   3      2/10/15 4:07
# 420  670454673    False   finalized                   3      2/10/15 2:16
#
#             birthplace  birthplace:confidence date_of_birth  \
# 184    London, England                    1.0          1972
# ...

# %%
df.sample(frac=0.01)
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 184  670454437    False   finalized                   3      2/10/15 1:56
# 493  670454746    False   finalized                   3      2/10/15 2:08
# 461  670454714    False   finalized                   3      2/10/15 2:15
# 359  670454612    False   finalized                   3      2/10/15 2:11
#
#               birthplace  birthplace:confidence date_of_birth  \
# 184      London, England                    1.0          1972
# 493           Queens, Ny                    1.0     28-Feb-48
# 461        St. Louis, Mo                    1.0     18-Aug-20
# 359  Dusseldorf, Germany                    1.0     12-Jan-10
#
#      date_of_birth:confidence race_ethnicity  ...                    award  \
# 184                       1.0          White  ...            Best Director
# 493                       1.0       Hispanic  ...  Best Supporting Actress
# ...

# %%
df[df['date_of_birth:confidence']==0.6667]
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 284  670454537    False   finalized                   3      2/10/15 2:07
# 408  670454661    False   finalized                   3      2/10/15 2:04
# 474  670454727    False   finalized                   3      2/10/15 2:04
#
#                    birthplace  birthplace:confidence date_of_birth  \
# 284  Vale of Glamorgan, Wales                    1.0   26-Sep-1875
# 408              Pasadena, Ca                    1.0      6-Nov-46
# 474              Columbus, Oh                    1.0     29-Mar-19
#
#      date_of_birth:confidence race_ethnicity  ...                    award  \
# 284                    0.6667          White  ...    Best Supporting Actor
# 408                    0.6667          White  ...             Best Actress
# 474                    0.6667          White  ...  Best Supporting Actress
#
#                                         biourl  birthplace_gold  \
# ...

# %% [markdown]
# ### 2.4 Subset Columns

# %% [markdown]
# #### 2.4.1 Single Column

# %%
df['_golden'] # pick one column - returns Series
# Out:
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: _golden, Length: 441, dtype: bool

# %%
df._golden
# Out:
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
#        ...
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# Name: _golden, Length: 441, dtype: bool

# %% [markdown]
# #### 2.4.2 Multiple Columns

# %%
df[['_unit_id', '_golden', '_unit_state']] # pick multiple columns - returns DataFrame
# Out:
#       _unit_id  _golden _unit_state
# 100  670454353    False   finalized
# 101  670454354    False   finalized
# 102  670454355    False   finalized
# 103  670454356    False   finalized
# 104  670454357    False   finalized
# ..         ...      ...         ...
# 536  670946276    False   finalized
# 537  670946299    False   finalized
# 538  670964912    False   finalized
# 539  670964956    False   finalized
# 540  670972898    False   finalized
#
# [441 rows x 3 columns]

# %%
df.filter(regex='date_of_birth')
# Out:
#     date_of_birth  date_of_birth:confidence date_of_birth_gold
# 100   30-Sep-1895                       1.0                NaN
# 101    2-Feb-1886                       1.0                NaN
# 102   30-Sep-1895                       1.0                NaN
# 103   23-Feb-1899                       1.0                NaN
# 104   23-Apr-1894                       1.0                NaN
# ..            ...                       ...                ...
# 536      7-Mar-71                       1.0                NaN
# 537     20-Oct-56                       1.0                NaN
# 538     26-Jul-22                       1.0                NaN
# 539     31-Aug-28                       1.0                NaN
# 540      5-Aug-06                       1.0                NaN
#
# [441 rows x 3 columns]

# %% [markdown]
# ### 2.5 Subset Rows and Columns

# %%
# the first condition is on rows, the second condition is on columns
df.loc[ df['date_of_birth:confidence']==1 , ['_unit_id', '_golden'] ]
# Out:
#       _unit_id  _golden
# 100  670454353    False
# 101  670454354    False
# 102  670454355    False
# 103  670454356    False
# 104  670454357    False
# ..         ...      ...
# 536  670946276    False
# 537  670946299    False
# 538  670964912    False
# 539  670964956    False
# 540  670972898    False
#
# [433 rows x 2 columns]

# %% [markdown]
# ## 2.6 Dropping rows, columns

# %%
# dropping columns
df.drop(['birthplace_gold', 'race_ethnicity'], axis=1)
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 100  670454353    False   finalized                   3      2/10/15 3:45
# 101  670454354    False   finalized                   3      2/10/15 2:03
# 102  670454355    False   finalized                   3      2/10/15 2:05
# 103  670454356    False   finalized                   3      2/10/15 2:04
# 104  670454357    False   finalized                   3      2/10/15 1:48
# ..         ...      ...         ...                 ...               ...
# 536  670946276    False   finalized                   3      2/10/15 2:00
# 537  670946299    False   finalized                   3      2/10/15 2:04
# 538  670964912    False   finalized                   3      2/10/15 2:03
# 539  670964956    False   finalized                   3      2/10/15 2:01
# 540  670972898    False   finalized                   3      2/10/15 2:01
#
#               birthplace  birthplace:confidence date_of_birth  \
# ...

# %%
# dropping duplicate rows
df.drop_duplicates()
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 100  670454353    False   finalized                   3      2/10/15 3:45
# 101  670454354    False   finalized                   3      2/10/15 2:03
# 102  670454355    False   finalized                   3      2/10/15 2:05
# 103  670454356    False   finalized                   3      2/10/15 2:04
# 104  670454357    False   finalized                   3      2/10/15 1:48
# ..         ...      ...         ...                 ...               ...
# 536  670946276    False   finalized                   3      2/10/15 2:00
# 537  670946299    False   finalized                   3      2/10/15 2:04
# 538  670964912    False   finalized                   3      2/10/15 2:03
# 539  670964956    False   finalized                   3      2/10/15 2:01
# 540  670972898    False   finalized                   3      2/10/15 2:01
#
#               birthplace  birthplace:confidence date_of_birth  \
# ...

# %% [markdown]
# ## 2.7 Summarize Data

# %%
# Numeric columns - calculates descriptive statistics
df.describe()
# Out:
#            _unit_id  _trusted_judgments  birthplace:confidence  \
# count  4.410000e+02          441.000000             441.000000
# mean   6.704825e+08            7.637188               0.995259
# std    1.139974e+05           19.015541               0.038917
# min    6.704544e+08            3.000000               0.657100
# 25%    6.704545e+08            3.000000               1.000000
# 50%    6.704546e+08            3.000000               1.000000
# 75%    6.704547e+08            3.000000               1.000000
# max    6.709729e+08           95.000000               1.000000
#
#        date_of_birth:confidence  race_ethnicity:confidence  \
# count                441.000000                 441.000000
# mean                   0.996607                   0.999130
# std                    0.032060                   0.016438
# min                    0.656200                   0.657100
# 25%                    1.000000                   1.000000
# ...

# %%
# Categorical columns - the unique values with their count of appearance in that column
df['_unit_state'].value_counts()
# Out:
# finalized    416
# golden        25
# Name: _unit_state, dtype: int64

# %%
# the count of unique elements in a column
df['_unit_state'].nunique()
# Out:
# 2

# %%
# Calculate the length of the DataFrame
len(df)
# Out:
# 441

# %%
# apply a function to summarize

# in-built functions - max, min, sum, count, median, mean, std, var
df.max() # max
# Out:
# _unit_id                                                         670972898
# _golden                                                               True
# _unit_state                                                         golden
# _trusted_judgments                                                      95
# birthplace                                  York, North Yorkshire, England
# birthplace:confidence                                                    1
# date_of_birth                                                     9-Sep-23
# date_of_birth:confidence                                                 1
# race_ethnicity                                                       White
# race_ethnicity:confidence                                                1
# religion                                                            Sufism
# religion:confidence                                                      1
# ...

# %%
# apply your custom function
def func(x):
    return x+1

df[['year_of_award', 'year_of_award:confidence']].apply(func)
# Out:
#      year_of_award  year_of_award:confidence
# 100           1928                    2.0000
# 101           1931                    2.0000
# 102           1932                    1.6667
# 103           1933                    2.0000
# 104           1934                    2.0000
# ..             ...                       ...
# 536           2007                    1.6857
# 537           2010                    2.0000
# 538           1978                    2.0000
# 539           2000                    2.0000
# 540           1950                    2.0000
#
# [441 rows x 2 columns]

# %% [markdown]
# ## 2.8 Group Data

# %%
# group by a set of columns and apply functions

# apply in-built functions directly

df.groupby(['year_of_award']).sum()
# Out:
#                  _unit_id  _golden  _trusted_judgments  birthplace:confidence  \
# year_of_award
# 1927            670454353      0.0                   3                 1.0000
# 1929           1340909044      0.0                   6                 2.0000
# 1930           3352272448      0.0                  15                 5.0000
# 1931           2011363405      0.0                   9                 3.0000
# 1932           2011363408      0.0                   9                 3.0000
# ...                   ...      ...                 ...                    ...
# 2010           3352764404      1.0                  98                 5.0000
# 2011           3352273011      0.0                  15                 5.0000
# 2012           3352273016      0.0                  15                 5.0000
# 2013           3352273021      0.0                  15                 4.6571
# 2014           2681818586      0.0                  12                 4.0000
#
# ...

# %%
# apply custom functions using agg
def custom_mean(x):
    return np.mean(x)+1

df.groupby(['year_of_award'])['_golden', '_trusted_judgments'].agg(custom_mean)
# Out:
#                _golden  _trusted_judgments
# year_of_award
# 1927               1.0                 4.0
# 1929               1.0                 4.0
# 1930               1.0                 4.0
# 1931               1.0                 4.0
# 1932               1.0                 4.0
# ...                ...                 ...
# 2010               1.2                20.6
# 2011               1.0                 4.0
# 2012               1.0                 4.0
# 2013               1.0                 4.0
# 2014               1.0                 4.0
#
# [87 rows x 2 columns]

# %% [markdown]
# ## 2.9 Missing values

# %%
# drop rows with any columns having NA
df.dropna()
# Out:
# Empty DataFrame
# Columns: [_unit_id, _golden, _unit_state, _trusted_judgments, _last_judgment_at, birthplace, birthplace:confidence, date_of_birth, date_of_birth:confidence, race_ethnicity, race_ethnicity:confidence, religion, religion:confidence, sexual_orientation, sexual_orientation:confidence, year_of_award, year_of_award:confidence, award, biourl, birthplace_gold, date_of_birth_gold, movie, person, race_ethnicity_gold, religion_gold, sexual_orientation_gold, year_of_award_gold]
# Index: []
#
# [0 rows x 27 columns]

# %%
# can apply on a column
df['_last_judgment_at'].dropna()
# Out:
# 100    2/10/15 3:45
# 101    2/10/15 2:03
# 102    2/10/15 2:05
# 103    2/10/15 2:04
# 104    2/10/15 1:48
#            ...
# 536    2/10/15 2:00
# 537    2/10/15 2:04
# 538    2/10/15 2:03
# 539    2/10/15 2:01
# 540    2/10/15 2:01
# Name: _last_judgment_at, Length: 416, dtype: object

# %% [markdown]
# ### 2.9.1 Replace missing values

# %%
# Replace missing values specific to each column
df.loc[df['_last_judgment_at'].isna(), '_last_judgment_at']
# Out:
# 121    NaN
# 133    NaN
# 152    NaN
# 182    NaN
# 211    NaN
# 252    NaN
# 279    NaN
# 305    NaN
# 313    NaN
# 335    NaN
# 363    NaN
# 380    NaN
# 389    NaN
# 393    NaN
# 400    NaN
# 422    NaN
# 428    NaN
# 443    NaN
# 447    NaN
# 477    NaN
# 501    NaN
# 502    NaN
# 507    NaN
# 511    NaN
# 530    NaN
# Name: _last_judgment_at, dtype: object

# %%
df.loc[df['_last_judgment_at'].isna(), '_last_judgment_at'] = df['_last_judgment_at'].mode()[0]

# %%
# use the boolean index to replace the NAs with a custom value
df[['birthplace_gold', 'race_ethnicity_gold']].fillna('Australia')
# Out:
#     birthplace_gold race_ethnicity_gold
# 100       Australia           Australia
# 101       Australia           Australia
# 102       Australia           Australia
# 103       Australia           Australia
# 104       Australia           Australia
# ..              ...                 ...
# 536       Australia           Australia
# 537       Australia           Australia
# 538       Australia           Australia
# 539       Australia           Australia
# 540       Australia           Australia
#
# [441 rows x 2 columns]

# %% [markdown]
# ## 2.10 Create new rows / columns

# %%
simple_df = pd.DataFrame({1:[1, 2, 3], 2:['a', 'b', 'c'], 3:[True, False, True]})

# %%
simple_df
# Out:
#    1  2      3
# 0  1  a   True
# 1  2  b  False
# 2  3  c   True

# %% [markdown]
# ### 2.10.1 Create new row using .loc

# %%
# add the new row using a new index value (3 here)
simple_df.loc[3] = [4, 'd', False]

# %%
simple_df
# Out:
#    1  2      3
# 0  1  a   True
# 1  2  b  False
# 2  3  c   True
# 3  4  d  False

# %% [markdown]
# ### 2.10.2 Create new column

# %%
simple_df
# Out:
#    1  2      3
# 0  1  a   True
# 1  2  b  False
# 2  3  c   True
# 3  4  d  False

# %%
# the new column should be of the same length as the df
simple_df[4] = [42, 2.3, 3, 65]

# %%
simple_df
# Out:
#    1  2      3     4
# 0  1  a   True  42.0
# 1  2  b  False   2.3
# 2  3  c   True   3.0
# 3  4  d  False  65.0

# %% [markdown]
# ## 2.11 Combining two dataframes

# %% [markdown]
# ### 2.11.1 Create new row by combining DataFrames

# %%
new_df = pd.DataFrame([[4, 'd', False]], columns=[1,2,3])

# %%
new_df
# Out:
#    1  2      3
# 0  4  d  False

# %%
# Concat function can be used for concatenating rows/columns
# if axis = 0 -> rows will be concatenated
# if axis = 1 -> columns will be concatenated
pd.concat([simple_df, new_df], axis=0)
# Out:
#    1  2      3
# 0  1  a   True
# 1  2  b  False
# 2  3  c   True
# 0  4  d  False

# %% [markdown]
# ### 2.11.2 Merge

# %% [markdown]
# Merge is like the join operation from SQL.
#
# You will merge two dataframes based on a column common between the two.
#
# Wherever the values of the column match in both dataframes, a new row which is a concat of both rows from A and B is formed

# %%
sales_df = pd.DataFrame([[1, 23, 100], [1, 45, 142], [2, 52, 45]], columns = ['customer_id', 'order_id', 'order_value'])
sales_df
# Out:
#    customer_id  order_id  order_value
# 0            1        23          100
# 1            1        45          142
# 2            2        52           45

# %%
customer_data = pd.DataFrame([[1, 'Male', 25], [2, 'Female', 49], [3, 'Female', 32]], columns = ['customer_id', 'gender', 'age'])

# %%
customer_data
# Out:
#    customer_id  gender  age
# 0            1    Male   25
# 1            2  Female   49
# 2            3  Female   32

# %%
# merge with a left condition - suggesting us to keep all rows from left dataframe
pd.merge(sales_df, customer_data, on="customer_id", how="left")
# Out:
#    customer_id  order_id  order_value  gender  age
# 0            1        23          100    Male   25
# 1            1        45          142    Male   25
# 2            2        52           45  Female   49

# %%
# merge with a right condition - suggesting us to keep all rows from right dataframe
pd.merge(sales_df, customer_data, on="customer_id", how="right")
# Out:
#    customer_id  order_id  order_value  gender  age
# 0            1      23.0        100.0    Male   25
# 1            1      45.0        142.0    Male   25
# 2            2      52.0         45.0  Female   49
# 3            3       NaN          NaN  Female   32

# %% [markdown]
# ## 2.12 Reshaping your DataFrame

# %% [markdown]
# ### 2.12.1 Sorting

# %%
# sort_values takes columns
df.sort_values(['_trusted_judgments'], ascending=False)
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 211  670454464     True      golden                  95      2/10/15 2:04
# 507  670454760     True      golden                  92      2/10/15 2:04
# 313  670454566     True      golden                  91      2/10/15 2:04
# 422  670454675     True      golden                  91      2/10/15 2:04
# 502  670454755     True      golden                  91      2/10/15 2:04
# ..         ...      ...         ...                 ...               ...
# 245  670454498    False   finalized                   3      2/10/15 2:10
# 244  670454497    False   finalized                   3      2/10/15 2:00
# 243  670454496    False   finalized                   3      2/10/15 2:03
# 242  670454495    False   finalized                   3      2/10/15 1:52
# 540  670972898    False   finalized                   3      2/10/15 2:01
#
#              birthplace  birthplace:confidence date_of_birth  \
# ...

# %% [markdown]
# ### 2.12.2 Reset index

# %%
df.reset_index()
# Out:
#      index   _unit_id  _golden _unit_state  _trusted_judgments  \
# 0      100  670454353    False   finalized                   3
# 1      101  670454354    False   finalized                   3
# 2      102  670454355    False   finalized                   3
# 3      103  670454356    False   finalized                   3
# 4      104  670454357    False   finalized                   3
# ..     ...        ...      ...         ...                 ...
# 436    536  670946276    False   finalized                   3
# 437    537  670946299    False   finalized                   3
# 438    538  670964912    False   finalized                   3
# 439    539  670964956    False   finalized                   3
# 440    540  670972898    False   finalized                   3
#
#     _last_judgment_at           birthplace  birthplace:confidence  \
# 0        2/10/15 3:45    Chisinau, Moldova                    1.0
# 1        2/10/15 2:03    Glasgow, Scotland                    1.0
# ...

# %% [markdown]
# ### 2.12.3 Pandas Melt

# %%
simple_df
# Out:
#    1  2      3     4
# 0  1  a   True  42.0
# 1  2  b  False   2.3
# 2  3  c   True   3.0
# 3  4  d  False  65.0

# %%
# keeps the columns in id_vars intact, takes columns in value_vars and creates a row for each entry
pd.melt(simple_df, id_vars=[1], value_vars=[2, 3])
# Out:
#    1  variable  value
# 0  1         2      a
# 1  2         2      b
# 2  3         2      c
# 3  4         2      d
# 4  1         3   True
# 5  2         3  False
# 6  3         3   True
# 7  4         3  False

# %% [markdown]
# ### 2.12.4 Pandas Pivot

# %%
simple_df
# Out:
#    1  2      3     4
# 0  1  a   True  42.0
# 1  2  b  False   2.3
# 2  3  c   True   3.0
# 3  4  d  False  65.0

# %%
# index columns get the index in the pivot output
# columns in column would be the columsn of the pivot output
# values represent the value that will be placed in the dataframe
# aggfunc can be used when there are multiple values in that position
# fill_value fills NaN with the argument value

pd.pivot_table(simple_df, index=[1], values=[4], columns=[2], aggfunc=np.mean, fill_value=0)
# Out:
#     4
# 2   a    b  c   d
# 1
# 1  42  0.0  0   0
# 2   0  2.3  0   0
# 3   0  0.0  3   0
# 4   0  0.0  0  65

# %% [markdown]
# ## 2.13 Plotting

# %%
df['birthplace:confidence'].plot.hist()

# %%
df.plot.scatter(x="_trusted_judgments", y="birthplace:confidence")
